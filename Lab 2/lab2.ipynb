# %%
import pandas as pd
import os

DATASET_DIR = "TINT"

data = []

for label in os.listdir(DATASET_DIR):
    label_path = os.path.join(DATASET_DIR, label)

    if os.path.isdir(label_path):
        for file in os.listdir(label_path):
            if file.lower().endswith((".jpg", ".png", ".jpeg")):
                data.append([
                    os.path.join(label_path, file),
                    label
                ])


df = pd.DataFrame(data, columns=["image_path", "label"]) #Load the dataset

df.shape #Display its shape
df.head() #Preview the first few rows
df.info() #Check column names and data types
df["label"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  165 non-null    str
#  1   label       165 non-null    str
# dtypes: str(2)
# memory usage: 2.7 KB
# label
# Heathly leaves     145
# infected leaves     20
# Name: count, dtype: int64
